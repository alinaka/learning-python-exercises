# %%
with open('dataset_24465_4 (2).txt') as file:
    data = file.read().split()

# %%
data
# Out:
# ['ei',
#  'w',
#  'woisqm',
#  'oeghi',
#  'omopejr',
#  'itmhhxmmgj',
#  'ltvd',
#  'ccfmcvsncl',
#  'vaftaaeqr',
#  'nkvp',
#  'hxtv',
#  'ht',
#  'jgwnmjlmkz',
#  'vstwubjx',
#  'tkvzwz',
#  'nwvyvkecx',
#  'pv',
#  'wwaqqub',
#  'nnkm',
#  'zk',
#  'gaubqgi',
#  'v',
#  'i',
#  'sqqfyg',
#  'hfhs',
#  'wosnfhh',
#  'p',
#  'hkepdw',
#  'ajyomlm',
#  'leiebrvtl',
#  'u',
#  'xdtuxstd',
#  'vmkgyczlm',
#  'fr',
#  'nthkyy',
#  'hws',
#  'bhg',
#  'pesormxogi',
#  'zbdcm',
#  'gzislrepl',
#  'lyltcllu',
#  'lbejyhwmxf',
#  'lruhqb',
#  'xp',
#  'n',
#  'heuj',
#  'rxammtq',
#  'hzbzzit',
#  'sj',
#  'dz',
#  'ifkvspttes',
#  'mgimjzftaa',
#  'hcyty',
#  'hqvgz',
#  'azaopsh',
#  'dtlpc',
#  'spvadmp',
#  'kcdbfuno',
#  'jkoyohyiq',
#  'ql',
#  'v',
#  'r',
#  'vqrzyotrhb',
#  'orp',
#  'zug',
#  'iiyboebcr',
#  'mnxe',
#  'lopoens',
#  'xbcfks',
#  'kllntuuca',
#  'rzze',
#  'oz',
#  'tnzjii',
#  'whmcuxkzs',
#  'zrakxnrpg',
#  'yyp',
#  'bcpon',
#  't',
#  'vbsksrx',
#  'ycynch',
# ...

# %%
data.reverse()

# %%
data
# Out:
# ['ogqfmr',
#  'ebhxnx',
#  'muwjyjcii',
#  'gqvqulwem',
#  'buknl',
#  'cooyalytp',
#  'mvr',
#  'paxsw',
#  'lwimql',
#  'ehaxcn',
#  'xytasio',
#  'fx',
#  'tlaxjzqbl',
#  'ndogavd',
#  'yburagwm',
#  'mkgreubzph',
#  'rufdoyioe',
#  'ghriazsg',
#  'wjlpfbd',
#  'dzpmu',
#  'uypssje',
#  'fcq',
#  'jpypdcb',
#  'i',
#  'mamhw',
#  'wpqbgjmrc',
#  'bxrevswyt',
#  'bpturla',
#  'ml',
#  'chfzbm',
#  'khx',
#  'mbbtns',
#  'q',
#  'nvpamdjwsk',
#  'whvxdqipa',
#  'joeyevzxl',
#  'slcbczob',
#  'blgthnp',
#  'nalsh',
#  'kzaydvu',
#  'fbsbqfwuyd',
#  'p',
#  'ttn',
#  'por',
#  'va',
#  'wgxrd',
#  'psq',
#  'irwqndmsb',
#  'awkcdkyt',
#  'kjrzja',
#  'spea',
#  'ucyjvfvak',
#  'honqfea',
#  'wre',
#  'lyxwyficlo',
#  'jkrbcsuv',
#  'gsumxrz',
#  'eiwgcvhoz',
#  'orxf',
#  'tpv',
#  'rhhci',
#  'tuifddsfp',
#  'hdfrcwzkqe',
#  'bywwermu',
#  'jizmufscy',
#  'vuqwnkq',
#  'pzh',
#  'bkjphai',
#  'skdvvjkr',
#  'xn',
#  'wqlasf',
#  'qvf',
#  'zcxraljlwm',
#  'gwvbyqhso',
#  'mfhieft',
# ...

# %%
result = '\n'.join(data)
with open('result.txt', 'w') as file:
    file.write(result)

# %%
result
# Out:
